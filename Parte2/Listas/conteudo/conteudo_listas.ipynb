# %% [markdown]
# #Lista
# link da documentação:
# https://docs.python.org/pt-br/3/tutorial/datastructures.html

# %% [markdown]
# ### Declarando listas

# %%
#lista vazia 
lista1 = []

#lista com elementos do tipo int
lista2 = [1,2,3,4]

#lista com elementos do tipo str
lista3 = ['casa', 'carro', 'bicicleta']

#lista com elementos de vários tipos
lista4  = [1, 'casa', [2,3]]

# %% [markdown]
# ### imprimindo elementos da lista

# %%
lista = ['casa', 'carro', 'bicicleta', 12, 89, 9.5, [3,5,4]]

#imprime a lista
print(lista)

#imprime o terceiro elemento da lista 
print(lista[2])

#penúltimo valor 
print(lista[-2])

#último valor
print(lista[-1])
# Out:
# ['casa', 'carro', 'bicicleta', 12, 89, 9.5, [3, 5, 4]]
# bicicleta
# 9.5
# [3, 5, 4]

# %%
frutas = ['morango', 'maçã', 'abacate', 'pera', 'manga', 'jabuticaba']

i = 0
while i<6:
  print(frutas[i])
  i = i+1
# Out:
# morango
# maçã
# abacate
# pera
# manga
# jabuticaba

# %% [markdown]
# ###Atualizando a lista

# %%
lista = ['um', 'dois', 'quatro']

lista[2] = 'três'

print(lista)
# Out:
# ['um', 'dois', 'três']

# %% [markdown]
# ### Tamanho da lista

# %%
frutas = ['morango', 'maçã', 'abacate', 'pera', 'manga', 'jabuticaba']

len(frutas)
# Out:
# 6

# %% [markdown]
# ### Para saber se uma determinada palavra está na lista (in)

# %%
frutas = ['morango', 'maçã', 'abacate', 'pera', 'manga', 'jabuticaba']

'abacate' in frutas
# Out:
# True

# %%
frutas = ['morango', 'maçã', 'abacate', 'pera', 'manga', 'jabuticaba']

if(('abacate' in frutas) == True):
  print('Abacate ESTÁ na lista')
else:
  print('Abacate NÃO está na lista')
# Out:
# Abacate ESTÁ na lista

# %% [markdown]
# ### "soma" e "multiplicação" de listas

# %%
a = [1,2,3]
b = [4,5,6]
#junta a lista "a" e "b"
c = [a+b]

#repete os valores 4 vezes 
d = [1,2,3]*4

print(c)
print(d)
# Out:
# [[1, 2, 3, 4, 5, 6]]
# [1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3]

# %% [markdown]
# ### Adicionando elementos na lista (append)

# %%
lista = [2]
lista.append("caderno")

print(lista)

lista.append([6,7,4])#insere a lista

print(lista)
# Out:
# [2, 'caderno']
# [2, 'caderno', [6, 7, 4]]

# %% [markdown]
# ### Adicionando elementos na lista (extend)

# %%
lista = [1,2,3]

lista.extend([6,7,4])#insere os elementos da lista 

print(lista)
# Out:
# [1, 2, 3, 6, 7, 4]

# %% [markdown]
# ### Adicionando elementos na lista (insert)

# %%
lista = [1,2,3]

lista.insert(0,"borracha") #insere o elemento no índice indicado

print(lista)
# Out:
# ['borracha', 1, 2, 3]

# %% [markdown]
# ### Removendo item de uma lista (remove)

# %%
lista = [1,2,3]

lista.remove(2)

print(lista)
# Out:
# [1, 3]

# %% [markdown]
# ### Removendo item de uma lista (pop)

# %%
lista = [1,2,3]

lista.pop() #remove o último item

print(lista)
# Out:
# [1, 2]

# %% [markdown]
# ### Removendo item de uma lista (del)

# %%
lista = [1,2,3]

del lista[1]
print(lista)
# Out:
# [1, 3]

# %% [markdown]
# ### limpando a lista (clear)

# %%
lista = [1,2,3]

lista.clear()#limpa a lista inteira

print(lista)

# %% [markdown]
# ### Acha o index do valor (index)

# %%
lista = [1, 2, "lala", "borracha", "a"]

lista.index("borracha")
# Out:
# 3

# %% [markdown]
# ### Conta a quantidade de vezes que o dado aparece na lista (count)

# %%
lista = [1, 2, "lala", "borracha", "a", "borracha"]

lista.count("borracha")
# Out:
# 2

# %% [markdown]
# ### Ordena lista numérica em ordem crescente (sort)

# %%
lista = [5,84,4,6,87,92,1]

lista.sort()

print(lista)
# Out:
# [1, 4, 5, 6, 84, 87, 92]

# %% [markdown]
# ### retorna o reverso da lista

# %%
lista1 = ['ola', 'mundo']
lista2 = [1,2,3,4,5]

lista1.reverse()
lista2.reverse()

print(lista1)
print(lista2)
# Out:
# ['mundo', 'ola']
# [5, 4, 3, 2, 1]

# %% [markdown]
# ##Listas aninhadas (listas de listas)
#
# As listas aninhadas são matrizes em python.

# %%
lista = [[1,2,3], [4,5,6], [7,8,9]]

print(lista)
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %% [markdown]
# ###Imprimindo o primeiro elemento da lista aninhada

# %%
lista[0]
# Out:
# [1, 2, 3]

# %% [markdown]
# ###Imprimindo um elemento [linha] [coluna]

# %%
lista[0][1]
# Out:
# 2

# %% [markdown]
# ###Concatenação de listas

# %%
lista1 = [1,2,3]
lista2 = [4,5,6]

lista3 = lista1 + lista2

print(lista3)
# Out:
# [1, 2, 3, 4, 5, 6]
