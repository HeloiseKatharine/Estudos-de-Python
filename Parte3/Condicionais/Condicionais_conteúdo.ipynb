# %% [markdown]
# #If - Else - Elif

# %%
if 5 > 2:
  print('Python')
# Out:
# Python

# %%
if 5 < 2:
  print('Python')
else:
  print('Erro')
# Out:
# Erro

# %% [markdown]
# ###Condicionais aninhados

# %%
idade = 18
if idade > 17:
  print('Você pode dirigir')
# Out:
# Você pode dirigir

# %%
nome = 'Bob'

if idade > 13:
  if nome == 'Bob':
    print("ok, você está autorizado a entrar")
  else:
    print('Desculpe, mas você não pode entrar!')
# Out:
# ok, você está autorizado a entrar

# %%
idade = 13 
nome = 'Bob'

if idade >= 13 and nome == 'Bob':
  print("ok, você está autorizado a entrar")
# Out:
# ok, você está autorizado a entrar

# %%
idade = 12
nome = 'Bob'

if (idade >= 13) or (nome == 'Bob'):
  print("ok, você está autorizado a entrar")
# Out:
# ok, você está autorizado a entrar

# %% [markdown]
# #Elif

# %%
dia = 'terça'
if dia == 'segunda':
  print('Hoje fará sol!')
else:
  print('Hoje vai chover!')
# Out:
# Hoje vai chover!

# %%
if dia == 'segunda':
  print('Hoje fará sol!')
elif dia == 'terça':
  print('Hoje vai chover!')
else:
  print('Sem previão do tempo para o dia selecionado')
# Out:
# Hoje vai chover!

# %% [markdown]
# ###Operadores Lógicos

# %%
#usando mais de uma condição na cláusula if 

disciplina = input('Digite o nome da disciplina: ')
nota_final = input('Digite a nota final (entre 0 e 100): ')

if disciplina == 'Geografia' and nota_final >= '70':
  print('Você foi aprovado!')
else:
  print('Lamento, acho que você precisa estudar mais!')
# Out:
# Digite o nome da disciplina: Geografia
# Digite a nota final (entre 0 e 100): 80
# Você foi aprovado!

# %%
#usando mais de uma condição na cláusula if e introduzindo placeholders

disciplina = input('Digite o nome da disciplina: ')
nota_final = input('Digite a nota final (entre 0 e 100): ')
semestre = input('Digite o semestre (1 a 4): ')

if disciplina == 'geografia' and nota_final >= '50' and int(semestre) != 1:
  print('Você foi aprovado em %s média fina %r!' %(disciplina, nota_final))
else:
  print('Lamento, acho que você precisa estudar mais!')
# Out:
# Digite o nome da disciplina: geografia
# Digite a nota final (entre 0 e 100): 60
# Digite o semestre (1 a 4): 4
# Você foi aprovado em geografia média fina '60'!
